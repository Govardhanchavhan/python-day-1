# %% [markdown]
# #PANDAS

# %%
# !pip install pandas    #python install package

# %%
import pandas as pd

# %%
#creating a dataframe

# %%
data = {'Name': ['Arya', 'Govardhan', 'Tushar'],
        'Age':[24,28,33],
        'City': ['wardha', 'washim', 'nagpur']}

# %%
data
# Out:
# {'Name': ['Arya', 'Govardhan', 'Tushar'],
#  'Age': [24, 28, 33],
#  'City': ['wardha', 'washim', 'nagpur']}

# %%
type(data)
# Out:
# dict

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#         Name  Age    City
# 0       Arya   24  wardha
# 1  Govardhan   28  washim
# 2     Tushar   33  nagpur

# %%
#list to df

# %%
list1 = [['arya', 23, 'wardha'], ['govardhan', 28, 'washim'], ['tushar', 33, 'nagpur']]

# %%
df1 = pd.DataFrame(list1, columns = ['Name', 'Age', 'City'])

# %%
df1
# Out:
#         Name  Age    City
# 0       arya   23  wardha
# 1  govardhan   28  washim
# 2     tushar   33  nagpur

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.info()      #dataframe structure info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.describe()      #to check mean, mode, max , all statastic values
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df['longitude']
# Out:
# 0       -114.31
# 1       -114.47
# 2       -114.56
# 3       -114.57
# 4       -114.57
#           ...
# 16995   -124.26
# 16996   -124.27
# 16997   -124.30
# 16998   -124.30
# 16999   -124.35
# Name: longitude, Length: 17000, dtype: float64

# %%
df[['longitude', 'latitude']]    #each column
# Out:
#        longitude  latitude
# 0        -114.31     34.19
# 1        -114.47     34.40
# 2        -114.56     33.69
# 3        -114.57     33.64
# 4        -114.57     33.57
# ...          ...       ...
# 16995    -124.26     40.58
# 16996    -124.27     40.69
# 16997    -124.30     41.84
# 16998    -124.30     41.80
# 16999    -124.35     40.54
#
# [17000 rows x 2 columns]

# %%
df.iloc[16992]             #by index location/ index number
# Out:
# longitude              -124.2300
# latitude                 40.8100
# housing_median_age       52.0000
# total_rooms            1112.0000
# total_bedrooms          209.0000
# population              544.0000
# households              172.0000
# median_income             3.3462
# median_house_value    50800.0000
# Name: 16992, dtype: float64

# %%
df.loc[16992]      #by label index name location
# Out:
# longitude              -124.2300
# latitude                 40.8100
# housing_median_age       52.0000
# total_rooms            1112.0000
# total_bedrooms          209.0000
# population              544.0000
# households              172.0000
# median_income             3.3462
# median_house_value    50800.0000
# Name: 16992, dtype: float64

# %%
# filter data by condition - latitude > 40

# %%
filtered_df = df[df['latitude']> 40]

# %%
filtered_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10315    -120.08     41.79                34.0       1355.0           262.0
# 10348    -120.12     41.40                33.0       2820.0           515.0
# 10388    -120.20     40.26                26.0       2399.0           518.0
# 10450    -120.35     40.63                33.0        240.0            49.0
# 10461    -120.37     40.17                21.0        789.0           141.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
filtered_df = df[(df['latitude']> 40) & (df['latitude'] < 41)]

# %%
filtered_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10388    -120.20     40.26                26.0       2399.0           518.0
# 10450    -120.35     40.63                33.0        240.0            49.0
# 10461    -120.37     40.17                21.0        789.0           141.0
# 10470    -120.38     40.98                27.0        777.0           185.0
# 10504    -120.42     40.38                26.0       1652.0           313.0
# ...          ...       ...                 ...          ...             ...
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df['New_House_Age'] = df['housing_median_age'] + 5    #create a new column in given system

# %%
df.head(1)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
#
#    population  households  median_income  median_house_value  New_House_Age
# 0      1015.0       472.0         1.4936             66900.0           20.0

# %%
df.isnull()    #missing value are have or not
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
df.isnull().sum()       #count missing value
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# New_House_Age         0
# dtype: int64

# %%
df.dropna(inplace= True)     # drop rows with missing value & na means null value

# %%
df.fillna(value= 13, inplace = True)    #fill the missing values with specific 13
